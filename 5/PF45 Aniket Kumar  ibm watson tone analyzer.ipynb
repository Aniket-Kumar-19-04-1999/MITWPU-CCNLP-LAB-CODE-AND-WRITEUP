# %%
# Sentiment Analysis Using IBM Watson Tone Analyzer API

# %%
pip install --upgrade "ibm-watson>=4.6.0"
# Out:
# Collecting ibm-watson>=4.6.0
#   Downloading https://files.pythonhosted.org/packages/9b/88/395d7d52df29f321ae1150cf9b5a71cef8611570230502597c427bc1e9d9/ibm-watson-5.1.0.tar.gz (382kB)
# Requirement already satisfied, skipping upgrade: requests<3.0,>=2.0 in c:\users\aniket\anaconda3\lib\site-packages (from ibm-watson>=4.6.0) (2.22.0)
# Requirement already satisfied, skipping upgrade: python_dateutil>=2.5.3 in c:\users\aniket\anaconda3\lib\site-packages (from ibm-watson>=4.6.0) (2.8.0)
# Requirement already satisfied, skipping upgrade: websocket-client==0.48.0 in c:\users\aniket\anaconda3\lib\site-packages (from ibm-watson>=4.6.0) (0.48.0)
# Collecting ibm_cloud_sdk_core>=3.3.6 (from ibm-watson>=4.6.0)
#   Downloading https://files.pythonhosted.org/packages/26/72/1f0c7beb208f355f80aeafc38919e418f1fa4953764bd177782ad1da640d/ibm-cloud-sdk-core-3.3.6.tar.gz
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\aniket\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm-watson>=4.6.0) (2019.9.11)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\aniket\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm-watson>=4.6.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\aniket\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm-watson>=4.6.0) (1.24.2)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\aniket\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm-watson>=4.6.0) (2.8)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\aniket\anaconda3\lib\site-packages (from python_dateutil>=2.5.3->ibm-watson>=4.6.0) (1.12.0)
# Collecting PyJWT<3.0.0,>=2.0.0a1 (from ibm_cloud_sdk_core>=3.3.6->ibm-watson>=4.6.0)
#   Downloading https://files.pythonhosted.org/packages/b4/9b/8850f99027ed029af6828199cc87179eaccbbf1f9e6e373e7f0177d32dad/PyJWT-2.0.1-py3-none-any.whl
# Building wheels for collected packages: ibm-watson, ibm-cloud-sdk-core
#   Building wheel for ibm-watson (setup.py): started
#   Building wheel for ibm-watson (setup.py): finished with status 'done'
#   Created wheel for ibm-watson: filename=ibm_watson-5.1.0-cp37-none-any.whl size=375442 sha256=67b6b47e45684bc31f2fb663a78cd2e8719d27eac647617190d3278b850e0ec3
#   Stored in directory: C:\Users\Aniket\AppData\Local\pip\Cache\wheels\49\6d\cf\1d91261b96363da78bf9b02699fd2262e6b5dad179500690c1
#   Building wheel for ibm-cloud-sdk-core (setup.py): started
#   Building wheel for ibm-cloud-sdk-core (setup.py): finished with status 'done'
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.3.6-cp37-none-any.whl size=55789 sha256=219a0066a02dc0d662ef305f0656597180ef7b384f1441dcb744c3baca5a86fc
#   Stored in directory: C:\Users\Aniket\AppData\Local\pip\Cache\wheels\49\1a\93\9c99ecd9fcfcdc862e4f4e61fc596db58f579fbb4c89da47b3
# Successfully built ibm-watson ibm-cloud-sdk-core
# Installing collected packages: PyJWT, ibm-cloud-sdk-core, ibm-watson
#   Found existing installation: PyJWT 1.7.1
#     Uninstalling PyJWT-1.7.1:
#       Successfully uninstalled PyJWT-1.7.1
#   Found existing installation: ibm-cloud-sdk-core 1.7.3
#     Uninstalling ibm-cloud-sdk-core-1.7.3:
#       Successfully uninstalled ibm-cloud-sdk-core-1.7.3
#   Found existing installation: ibm-watson 5.0.2
#     Uninstalling ibm-watson-5.0.2:
#       Successfully uninstalled ibm-watson-5.0.2
# Successfully installed PyJWT-2.0.1 ibm-cloud-sdk-core-3.3.6 ibm-watson-5.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('0w53ZeLXNDXySWlPrj4-gAKbJ5i0k53O-CdS4Jxun5Sf')
tone_analyzer = ToneAnalyzerV3(
    version='2017-09-21',
    authenticator=authenticator
)

tone_analyzer.set_service_url('https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/7929578f-79e4-4749-8b55-b8dced09fb4f')

text = 'I got a wild hair for taffy and ordered this five pound bag.\
        The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc.\
        My only complaint is there was a bit too much red/black licorice-flavored pieces (just not my particular favorites).\
        Between me, my kids, and my husband, this lasted only two weeks! I would recommend this brand of taffy it was a delightful treat.'
tone_analysis = tone_analyzer.tone(
    {'text': text},
    content_type='application/json'
).get_result()
print(json.dumps(tone_analysis, indent=2))
# Out:
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.577153,
#         "tone_id": "joy",
#         "tone_name": "Joy"
#       },
#       {
#         "score": 0.661159,
#         "tone_id": "confident",
#         "tone_name": "Confident"
#       }
#     ]
#   },
#   "sentences_tone": [
#     {
#       "sentence_id": 0,
#       "text": "I got a wild hair for taffy and ordered this five pound bag.",
#       "tones": []
#     },
#     {
#       "sentence_id": 1,
#       "text": "The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc.",
#       "tones": [
#         {
#           "score": 0.898327,
#           "tone_id": "confident",
#           "tone_name": "Confident"
#         }
#       ]
#     },
#     {
#       "sentence_id": 2,
#       "text": "My only complaint is there was a bit too much red/black licorice-flavored pieces (just not my particular favorites).",
#       "tones": [
#         {
#           "score": 0.567744,
#           "tone_id": "tentative",
#           "tone_name": "Tentative"
#         }
#       ]
#     },
#     {
#       "sentence_id": 3,
#       "text": "Between me, my kids, and my husband, this lasted only two weeks!",
#       "tones": []
#     },
#     {
#       "sentence_id": 4,
#       "text": "I would recommend this brand of taffy it was a delightful treat.",
#       "tones": []
#     }
#   ]
# }

# %%
import json
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('0w53ZeLXNDXySWlPrj4-gAKbJ5i0k53O-CdS4Jxun5Sf')
tone_analyzer = ToneAnalyzerV3(
    version='2017-09-21',
    authenticator=authenticator
)

tone_analyzer.set_service_url('https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/7929578f-79e4-4749-8b55-b8dced09fb4f')

utterances = [
    {
        "text": "Hello, I'm having a problem with your product.",
        "user": "customer"
    },
    {
        "text": "OK, let me know what's going on, please.",
        "user": "agent"
    },
    {
        "text": "Well, nothing is working :(",
        "user": "customer"
    },
    {
        "text": "Sorry to hear that.",
        "user": "agent"
    }
]

utterance_analyses = tone_analyzer.tone_chat(utterances).get_result()
print(json.dumps(utterance_analyses, indent=2))
# Out:
# {
#   "utterances_tone": [
#     {
#       "utterance_id": 0,
#       "utterance_text": "Hello, I'm having a problem with your product.",
#       "tones": [
#         {
#           "score": 0.686361,
#           "tone_id": "polite",
#           "tone_name": "Polite"
#         }
#       ]
#     },
#     {
#       "utterance_id": 1,
#       "utterance_text": "OK, let me know what's going on, please.",
#       "tones": [
#         {
#           "score": 0.92724,
#           "tone_id": "polite",
#           "tone_name": "Polite"
#         }
#       ]
#     },
#     {
#       "utterance_id": 2,
#       "utterance_text": "Well, nothing is working :(",
#       "tones": [
#         {
#           "score": 0.997795,
#           "tone_id": "sad",
#           "tone_name": "Sad"
#         }
#       ]
#     },
#     {
#       "utterance_id": 3,
#       "utterance_text": "Sorry to hear that.",
#       "tones": [
#         {
#           "score": 0.730982,
#           "tone_id": "polite",
#           "tone_name": "Polite"
#         },
#         {
#           "score": 0.672499,
#           "tone_id": "sympathetic",
#           "tone_name": "Sympathetic"
#         }
#       ]
#     }
#   ]
# }
